# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

# %% [markdown]
# # Problem 6

# %% [markdown]
# Generate an i.i.d. sample $x_1, \ldots, x_n, n=11, \alpha = 3, k = 2$ from a Pareto distribution with density
#
# $$
# f(x) = \frac{\alpha k^{\alpha}}{x^{\alpha + 1}}, \quad 0 < k < x, \: \: \alpha > 2.
# $$
#
# **(a)** Give a plug in estimator for $\alpha$ and $\theta = \frac{\alpha}{(\alpha-1)^2(\alpha-2)}$
#
# **(b)** Calculate a bootstrap confidence interval for $\theta$.

# %% [markdown]
# # Solution
#
# We formalize our solution according to the $7$ step Bootstrap process.

# %% [markdown]
# ## 1. Model
#
# Suppose $ \mathbf{X} = (X_1, \ldots, X_{11}) $ is an i.i.d. sample where $ X \sim \text{Par}(\alpha, k) $ with distribution function $F(x) = \alpha k^{\alpha}/x^{\alpha + 1}, 0 < k < x, \: \alpha > 2. $
#
# ## 2. Goal
#
# We are interested in the parameter plug-in estimators $\widehat{\alpha}$, $\widehat{\theta} = \frac{\widehat{\alpha}}{(\widehat{\alpha}-1)^2(\widehat{\alpha}-2)}$ and the bootstrap confidence interval for $\widehat{\theta}$.
#
# ## 3. Experiment in the real world
#
# We generate an i.i.d. sample $\mathbf{x} = (x_1, \ldots, x_{11})$ from Par($\alpha, k$), $\alpha = 3, k = 2$.

# %%
# Setting the parameters
k = 2
alpha = 3
n = 11

# %%
# Sample numpy
x = (np.random.pareto(alpha, n) + 1) * k

# %% [markdown]
# ## Bonus: MLE for $\alpha$

# %%
alphaGrid = np.linspace(0.1, 10, 1000)
logLike = n*np.log(alphaGrid) + n*alphaGrid*np.log(k) - (1+alphaGrid)*np.sum(np.log(x))
alphaHat = n/(np.sum(np.log(x)) - n*np.log(k))

# %%
plt.plot(alphaGrid, logLike, color='black')
plt.axvline(alphaHat, color='gray', linestyle='dashed')
plt.show()

# %% [markdown]
# ## 4. Approximation step
#
# We enter bootstrap world and estimate $ F(x) $ with the empirical distribution function (EDF) $ \widehat{F}_n(z) = \frac{1}{n} \sum_{k=1}^n I \left\{ x_k \leq z \right\}. $ We define $ \mathbf{P}^* $ as the distribution belonging to $ \widehat{F}_n(z) $.

# %%
res = ECDF(x)

plt.plot(res.x, res.y)
plt.title("Empirical Distribution Function")
plt.show()

# %% [markdown]
# ## 5. Experiment in the bootstrap world
#
# We independently draw $ B $ random samples $ \mathbf{x}_{(j)}^* $ of size $ n $ from $ \mathbf{P}^* $, $ j = 1, \ldots, B, $ with
# $$
# \mathbf{X}_{(j)}^* = \left( X_{1j}^*, \ldots, X_{nj}^* \right) \sim \mathbf{P}^*
# \quad  \text{and} \quad
# \mathbf{x}_{(j)}^* = (x_{1j}^*, \ldots, x_{nj}^*),
# $$
# where $ \mathbf{x}_{(j)}^* $ are our bootstrap samples. In our experiment, drawing samples from the empirical distribution $ \mathbf{P}^* $ equates to drawing samples uniformly with replacement from $ \mathbf{x} $.

# %%
B = 1000
repl = np.random.choice(x, size=(B,n), replace=True, p=None)

# %% [markdown]
# ## 6. Estimation in the bootstrap world
#
# We calculate the plug-in estimators for
# each bootstrap sample $\widehat{\alpha}_{(j)}^* = \widehat{\alpha}(\mathbf{x}_{(j)}^*),
# \widehat{\theta}_{(j)}^* = \widehat{\theta}(\mathbf{x}_{(j)}^*).$
# We use maximum likelihood estimation (MLE) to find $\widehat{\alpha}$ and begin with deriving
# the log likelihood of $ \alpha $ conditioned on $ k $:
# \begin{align*}
#     \ell(\alpha | k, \mathbf{x}) &= \log_{} (F(\mathbf{x} | \alpha, k)) \\
#     &= \log_{} \prod_{i=1}^{n} F(x_i | \alpha, k) \\
#     &= \log_{} \prod_{i=1}^{n} \frac{\alpha k^{\alpha}}{x_i^{\alpha + 1}} \\
#     &= \log_{} \frac{\alpha^n k ^{n \alpha}}{\prod_{i=1}^{n}x_i ^{\alpha + 1}} \\
#     &= n \log_{} (\alpha) + n \alpha \log_{}(k) - (1 + \alpha) \sum_{i=1}^n \log_{}(x_i).
# \end{align*}
# The MLE, $ \widehat{\alpha}, $ is the maxima such that
# \begin{gather*}
#     \frac{\partial \ell}{\partial \alpha} \Bigg|_{\alpha = \widehat{\alpha}}^{}
#     = \frac{n}{\alpha} + n \log_{} (k) - \sum_{i=1}^n \log_{} (x_i) = 0 \\
#     \Rightarrow \widehat{\alpha} = \frac{n}{\sum_{i=1}^n \log_{}(x_i) - n \log_{}(k)}.
# \end{gather*}
# Consequently,
# $$
# \widehat{\theta} = \frac{\widehat{\alpha}}{(\widehat{\alpha}-1)^2 (\widehat{\alpha} - 2)}.
# $$

# %%
alphaHatBoot = np.zeros(B)

for i in range(B):
    alphaHatBoot[i] = n/(np.sum(np.log(repl[i])) - n*np.log(k))

thetaHatBoot = alphaHatBoot / ((alphaHatBoot - 1)**2 * (alphaHatBoot - 2))

# %%
print(f'Mean alphaHatBoot = {np.mean(alphaHatBoot)}')
print(f'Mean thetaHatBoot = {np.mean(thetaHatBoot)}')
# Out:
# Mean alphaHatBoot = 3.8601772088504056
# Mean thetaHatBoot = 0.40524947566217817

# %%
print(f'Std alphaHatBoot = {np.std(alphaHatBoot)}')
print(f'Std thetaHatBoot = {np.std(thetaHatBoot)}')
# Out:
# Std alphaHatBoot = 0.8441055323191919
# Std thetaHatBoot = 0.46464408328330586

# %% [markdown]
# ## 7. Inference in the bootstrap world
#
# Finally, we use the bootstrap replications to
# calculate the percentile bootstrap confidence interval for $ \widehat{\theta} $. Let
# $ \widehat{\theta}_{[1]}^* \leq \widehat{\theta}_{[2]}^* \leq \ldots \leq \widehat{\theta}_{[j]}^*
# \leq \ldots \leq \widehat{\theta}_{[B]}^* $ be the ordered bootstrap replications. Then the
# percentile bootstrap interval is given by
# $$
# \left[ \widehat{\theta}_{[(1 + B)(\alpha)]}^*, \widehat{\theta}_{[(1 + B)(1-\alpha)]}^*  \right].
# $$
# In our case, we calculate the 95\% confidence interval.

# %%
# Percentile Bootstrap Confidence Interval
lower = np.percentile(thetaHatBoot, 2.5)
upper = np.percentile(thetaHatBoot, 97.5)
print(lower, upper)
# Out:
# 0.07032630084354781 1.3170428444753415
